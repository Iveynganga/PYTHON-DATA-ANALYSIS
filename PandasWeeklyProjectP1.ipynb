# %% [markdown]
# <a href="https://colab.research.google.com/github/Iveynganga/PYTHON-DATA-ANALYSIS/blob/main/PandasWeeklyProjectP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv"

apple_stock = pd.read_csv(url)

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv"

apple = pd.read_csv(url)

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
column_types = apple.dtypes

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
import pandas as pd

apple['Date'] = pd.to_datetime(apple['Date'])

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index('Date', inplace=True)

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
duplicate_dates = apple.index.duplicated().any()

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple.sort_index(inplace=True)

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
import pandas as pd

last_business_days = apple.resample('BM').last()

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
difference_in_days = (apple.index.max() - apple.index.min()).days

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
num_months = len(apple.resample('M'))

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(13.5, 9))
apple['Adj Close'].plot()

plt.title('Apple Stock - Adjusted Close')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Value')
# Out:
# Text(0, 0.5, 'Adjusted Close Value')

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# How can you remove duplicate rows from a DataFrame in pandas?

# %%
import pandas as pd

data = {'A': [1, 2, 2, 3, 4],
        'B': ['a', 'b', 'b', 'c', 'd']}
df = pd.DataFrame(data)

df_no_duplicates = df.drop_duplicates()
